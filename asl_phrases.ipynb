# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False                  # non - writeable mode
    results = model.process(image)                 # prediction
    image.flags.writeable = True                   # writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

# %%
def draw_styled_landmarks(img, results):
    mp_drawing.draw_landmarks(img, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(80,44,121),thickness=2, circle_radius=2))
    mp_drawing.draw_landmarks(img, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(121,44,250),thickness=2, circle_radius=2))
    mp_drawing.draw_landmarks(img, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, lh, rh])

# %%
DATA_PATH = os.path.join('PHRASES_DATASET')
actions = np.array(['hello', 'bye', 'yes', 'no', 'please'])
no_sequence = 40
sequence_length = 20
WIDTH = 640
HEIGHT = 480

# %%
for action in actions:
    for sequence in range(no_sequence):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)

# Access mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    for action in actions:
        for sequence in range(29, no_sequence):
            cv2.waitKey(1000)
            for frame_num in range(sequence_length):
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Landmarks
                draw_styled_landmarks(image, results)
                
                if frame_num == 0:
                    cv2.waitKey(400)
    
                    cv2.putText(image, 'frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)

                else:
                    cv2.putText(image, 'frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)


                
                # keypoint extraction
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)
                
                # Show the frame
                cv2.imshow('OpenCV Feed', image)
                

                # Release on q
                if cv2.waitKey(10) & 0xFF == ord('q'):
                             break
    cap.release()
    cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label: num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'bye': 1, 'yes': 2, 'no': 3, 'please': 4}

# %%
import random

def get_random_list(sequence_length=90, sequence=60):   
    num_list = []

    while len(num_list) < sequence:
        num = random.randint(0, sequence_length-1)
        if num not in num_list:
            num_list.append(num)

    return num_list

# %%
sequences, labels = [], []

for action in actions:
    for sequence in get_random_list(40, 20):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), str(frame_num) + '.npy'))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (150, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (150,)

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.05)

# %%
y_test.shape
# Out:
# (8, 5)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(20,258)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=300)
# Out:
# Epoch 1/300
# 2023-05-14 22:03:42.806241: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 5/5 [==============================] - 20s 4s/step - loss: 1.6869 - categorical_accuracy: 0.1338
# Epoch 2/300
# 5/5 [==============================] - 17s 3s/step - loss: 2.2226 - categorical_accuracy: 0.1972
# Epoch 3/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.6127 - categorical_accuracy: 0.1901
# Epoch 4/300
# 5/5 [==============================] - 17s 3s/step - loss: 2.4903 - categorical_accuracy: 0.1831
# Epoch 5/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.7537 - categorical_accuracy: 0.3239
# Epoch 6/300
# 5/5 [==============================] - 17s 4s/step - loss: 1.6813 - categorical_accuracy: 0.1690
# Epoch 7/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.5524 - categorical_accuracy: 0.4155
# Epoch 8/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.6178 - categorical_accuracy: 0.2254
# Epoch 9/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.6944 - categorical_accuracy: 0.2394
# Epoch 10/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.6155 - categorical_accuracy: 0.1690
# Epoch 11/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.6005 - categorical_accuracy: 0.1831
# Epoch 12/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.6042 - categorical_accuracy: 0.2113
# Epoch 13/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.5950 - categorical_accuracy: 0.2254
# Epoch 14/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.5870 - categorical_accuracy: 0.1901
# Epoch 15/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.5718 - categorical_accuracy: 0.1901
# Epoch 16/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.5555 - categorical_accuracy: 0.1901
# Epoch 17/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.5086 - categorical_accuracy: 0.1620
# Epoch 18/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4948 - categorical_accuracy: 0.3732
# Epoch 19/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4568 - categorical_accuracy: 0.3732
# Epoch 20/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4320 - categorical_accuracy: 0.3873
# Epoch 21/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.5597 - categorical_accuracy: 0.2606
# Epoch 22/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4756 - categorical_accuracy: 0.3310
# Epoch 23/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4148 - categorical_accuracy: 0.3380
# Epoch 24/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.3879 - categorical_accuracy: 0.4789
# Epoch 25/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.3054 - categorical_accuracy: 0.4577
# Epoch 26/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.2198 - categorical_accuracy: 0.4789
# Epoch 27/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.2320 - categorical_accuracy: 0.4859
# Epoch 28/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.3562 - categorical_accuracy: 0.4437
# Epoch 29/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.2868 - categorical_accuracy: 0.4437
# Epoch 30/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.1606 - categorical_accuracy: 0.4648
# Epoch 31/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.0361 - categorical_accuracy: 0.5070
# Epoch 32/300
# 5/5 [==============================] - 17s 3s/step - loss: 4.7087 - categorical_accuracy: 0.2183
# Epoch 33/300
# 5/5 [==============================] - 17s 3s/step - loss: 2.2496 - categorical_accuracy: 0.1972
# Epoch 34/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.6563 - categorical_accuracy: 0.1901
# Epoch 35/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.5873 - categorical_accuracy: 0.2183
# Epoch 36/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.5295 - categorical_accuracy: 0.2535
# Epoch 37/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4978 - categorical_accuracy: 0.4014
# Epoch 38/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4372 - categorical_accuracy: 0.4507
# Epoch 39/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.7546 - categorical_accuracy: 0.4366
# Epoch 40/300
# 5/5 [==============================] - 17s 3s/step - loss: 2.4210 - categorical_accuracy: 0.2042
# Epoch 41/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.6056 - categorical_accuracy: 0.2606
# Epoch 42/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.5068 - categorical_accuracy: 0.2394
# Epoch 43/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4980 - categorical_accuracy: 0.2746
# Epoch 44/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4638 - categorical_accuracy: 0.3310
# Epoch 45/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4312 - categorical_accuracy: 0.4437
# Epoch 46/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4140 - categorical_accuracy: 0.4930
# Epoch 47/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.3488 - categorical_accuracy: 0.4014
# Epoch 48/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.3178 - categorical_accuracy: 0.5493
# Epoch 49/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.2941 - categorical_accuracy: 0.5282
# Epoch 50/300
# 5/5 [==============================] - 18s 4s/step - loss: 1.2668 - categorical_accuracy: 0.4507
# Epoch 51/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.2059 - categorical_accuracy: 0.5423
# Epoch 52/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.5449 - categorical_accuracy: 0.3873
# Epoch 53/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.4983 - categorical_accuracy: 0.3803
# Epoch 54/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.2720 - categorical_accuracy: 0.4789
# Epoch 55/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.3791 - categorical_accuracy: 0.3944
# Epoch 56/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.3219 - categorical_accuracy: 0.4437
# Epoch 57/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.0636 - categorical_accuracy: 0.4648
# Epoch 58/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.3025 - categorical_accuracy: 0.4718
# Epoch 59/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.2428 - categorical_accuracy: 0.3380
# Epoch 60/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.2114 - categorical_accuracy: 0.5070
# Epoch 61/300
# 5/5 [==============================] - 17s 4s/step - loss: 1.1558 - categorical_accuracy: 0.5704
# Epoch 62/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.1136 - categorical_accuracy: 0.6338
# Epoch 63/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.0236 - categorical_accuracy: 0.6690
# Epoch 64/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.2019 - categorical_accuracy: 0.4507
# Epoch 65/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.9750 - categorical_accuracy: 0.6690
# Epoch 66/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.0343 - categorical_accuracy: 0.5352
# Epoch 67/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.9940 - categorical_accuracy: 0.5915
# Epoch 68/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.0102 - categorical_accuracy: 0.5423
# Epoch 69/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.8893 - categorical_accuracy: 0.6127
# Epoch 70/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.7389 - categorical_accuracy: 0.6901
# Epoch 71/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.7460 - categorical_accuracy: 0.7042
# Epoch 72/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.8420 - categorical_accuracy: 0.5915
# Epoch 73/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.9646 - categorical_accuracy: 0.5141
# Epoch 74/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.8768 - categorical_accuracy: 0.5704
# Epoch 75/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.7347 - categorical_accuracy: 0.6620
# Epoch 76/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.6597 - categorical_accuracy: 0.7394
# Epoch 77/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.5848 - categorical_accuracy: 0.7817
# Epoch 78/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.6254 - categorical_accuracy: 0.6831
# Epoch 79/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.5777 - categorical_accuracy: 0.7394
# Epoch 80/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.8435 - categorical_accuracy: 0.5775
# Epoch 81/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.5050 - categorical_accuracy: 0.7958
# Epoch 82/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.4620 - categorical_accuracy: 0.8099
# Epoch 83/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.4210 - categorical_accuracy: 0.8380
# Epoch 84/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.5031 - categorical_accuracy: 0.7606
# Epoch 85/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.7222 - categorical_accuracy: 0.4507
# Epoch 86/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.3291 - categorical_accuracy: 0.4296
# Epoch 87/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.0382 - categorical_accuracy: 0.4930
# Epoch 88/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.9614 - categorical_accuracy: 0.5282
# Epoch 89/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.8883 - categorical_accuracy: 0.6408
# Epoch 90/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.7671 - categorical_accuracy: 0.6901
# Epoch 91/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.7190 - categorical_accuracy: 0.6972
# Epoch 92/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.6599 - categorical_accuracy: 0.7535
# Epoch 93/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.6264 - categorical_accuracy: 0.7606
# Epoch 94/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.5400 - categorical_accuracy: 0.7958
# Epoch 95/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.4753 - categorical_accuracy: 0.8028
# Epoch 96/300
# 5/5 [==============================] - 18s 4s/step - loss: 0.4559 - categorical_accuracy: 0.7606
# Epoch 97/300
# 5/5 [==============================] - 18s 3s/step - loss: 0.3834 - categorical_accuracy: 0.8803
# Epoch 98/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.3578 - categorical_accuracy: 0.8380
# Epoch 99/300
# 5/5 [==============================] - 18s 3s/step - loss: 0.3239 - categorical_accuracy: 0.8662
# Epoch 100/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.5521 - categorical_accuracy: 0.7535
# Epoch 101/300
# 5/5 [==============================] - 17s 3s/step - loss: 2.8946 - categorical_accuracy: 0.3803
# Epoch 102/300
# 5/5 [==============================] - 18s 3s/step - loss: 1.8633 - categorical_accuracy: 0.3803
# Epoch 103/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.3976 - categorical_accuracy: 0.3451
# Epoch 104/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.3679 - categorical_accuracy: 0.3380
# Epoch 105/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.2953 - categorical_accuracy: 0.4225
# Epoch 106/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.2463 - categorical_accuracy: 0.4014
# Epoch 107/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.1763 - categorical_accuracy: 0.4085
# Epoch 108/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.1176 - categorical_accuracy: 0.4859
# Epoch 109/300
# 5/5 [==============================] - 17s 3s/step - loss: 1.0396 - categorical_accuracy: 0.5563
# Epoch 110/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.9435 - categorical_accuracy: 0.6197
# Epoch 111/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.7190 - categorical_accuracy: 0.7042
# Epoch 112/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.5747 - categorical_accuracy: 0.7606
# Epoch 113/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.6993 - categorical_accuracy: 0.6549
# Epoch 114/300
# 5/5 [==============================] - 18s 4s/step - loss: 0.6511 - categorical_accuracy: 0.6620
# Epoch 115/300
# 5/5 [==============================] - 18s 4s/step - loss: 0.5932 - categorical_accuracy: 0.7465
# Epoch 116/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.6527 - categorical_accuracy: 0.6479
# Epoch 117/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.5960 - categorical_accuracy: 0.6620
# Epoch 118/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.5690 - categorical_accuracy: 0.7324
# Epoch 119/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.4327 - categorical_accuracy: 0.8380
# Epoch 120/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.3883 - categorical_accuracy: 0.8310
# Epoch 121/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.3361 - categorical_accuracy: 0.8732
# Epoch 122/300
# 5/5 [==============================] - 18s 4s/step - loss: 1.3500 - categorical_accuracy: 0.5493
# Epoch 123/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.6946 - categorical_accuracy: 0.6479
# Epoch 124/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.6546 - categorical_accuracy: 0.7324
# Epoch 125/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.7115 - categorical_accuracy: 0.6972
# Epoch 126/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.7013 - categorical_accuracy: 0.6901
# Epoch 127/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.5750 - categorical_accuracy: 0.7465
# Epoch 128/300
# 5/5 [==============================] - 18s 4s/step - loss: 0.4624 - categorical_accuracy: 0.8451
# Epoch 129/300
# 5/5 [==============================] - 18s 4s/step - loss: 0.3842 - categorical_accuracy: 0.8521
# Epoch 130/300
# 5/5 [==============================] - 19s 4s/step - loss: 0.3377 - categorical_accuracy: 0.9155
# Epoch 131/300
# 5/5 [==============================] - 18s 3s/step - loss: 0.3473 - categorical_accuracy: 0.8380
# Epoch 132/300
# 5/5 [==============================] - 19s 4s/step - loss: 0.3644 - categorical_accuracy: 0.8239
# Epoch 133/300
# 5/5 [==============================] - 18s 4s/step - loss: 0.4602 - categorical_accuracy: 0.7958
# Epoch 134/300
# 5/5 [==============================] - 19s 4s/step - loss: 0.6297 - categorical_accuracy: 0.7465
# Epoch 135/300
# 5/5 [==============================] - 20s 4s/step - loss: 0.6014 - categorical_accuracy: 0.7394
# Epoch 136/300
# 5/5 [==============================] - 20s 4s/step - loss: 0.4884 - categorical_accuracy: 0.7746
# Epoch 137/300
# 5/5 [==============================] - 18s 4s/step - loss: 0.4759 - categorical_accuracy: 0.7887
# Epoch 138/300
# 5/5 [==============================] - 17s 3s/step - loss: 0.4043 - categorical_accuracy: 0.8662
# Epoch 139/300
# 5/5 [==============================] - 18s 4s/step - loss: 0.3265 - categorical_accuracy: 0.8662
# Epoch 140/300
# 5/5 [==============================] - 18s 4s/step - loss: 0.2985 - categorical_accuracy: 0.8662
# Epoch 141/300
# 5/5 [==============================] - 18s 3s/step - loss: 0.2630 - categorical_accuracy: 0.9085
# Epoch 142/300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 model.fit(X_train, y_train, epochs=300)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/keras/engine/training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save('')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model.load_weights('/Users/ablayaman/Desktop/diploma_asl_project/ASL_PHRASES/phrases_052023.h5')

# %%
import random
import pyperclip
def generate_colors(n_colors):
    colors = []
    for i in range(n_colors):
        r = random.randint(0, 255)
        g = random.randint(0, 255)
        b = random.randint(0, 255)
        colors.append([r,g,b])
    return colors

# %%
colors = generate_colors(len(actions))
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, f'{actions[num]} {str(prob*100)[:4]}%', (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
sequence = []
confirmed = []
predictions = []
sentence = []
threshold = 0.7
counter = 0
cap = cv2.VideoCapture(0)
cap.set(3, WIDTH)
cap.set(4, HEIGHT)
sentence_len = 0
# mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # detections
        image, results = mediapipe_detection(frame, holistic)        
        # landmarks
        draw_styled_landmarks(image, results)
        
#       Make Predictions 
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-20:]
        if len(sequence) == 20:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            predictions.append(np.argmax(res))

            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold:
                    if len(sentence) == 0:
                        sentence.append(actions[np.argmax(res)])
                    else:
                        sentence[-1] = actions[np.argmax(res)]
#                     else:
#                         sentence.append(actions[np.argmax(res)])
            if cv2.waitKey(1) == 13:
                sentence.append(actions[np.argmax(res)])
                confirmed = sentence[:-1]
                counter += 1
            if len(sentence) > 10: 
                sentence = sentence[-10:]

            image = prob_viz(res, actions, image, colors)
            cv2.rectangle(image, (0,0), (1280, 50), (245, 117, 16), -1)
            cv2.putText(image, ' '.join(sentence), (3,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(image, ' '.join(confirmed), (3,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, ( 0, 255, 0), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('ASL Detection', image)

        # Break
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        elif cv2.waitKey(1) & 0xFF == ord('c'):
            pyperclip.copy(' '.join(sentence))
        elif cv2.waitKey(1) & 0xFF == ord('s'):
            if len(sentence) != 0:
                save_signed_text(' '.join(sentence[:-1]))
            
            
            
    cap.release()
    cv2.destroyAllWindows()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# 2023-05-17 17:12:37.986966: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 141ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 14
#      12 with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#      13     while cap.isOpened():
# ---> 14         ret, frame = cap.read()
#      16         # detections
#      17         image, results = mediapipe_detection(frame, holistic)
#
# KeyboardInterrupt:
